# %% [markdown]
# # Predefined Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('daily-min-temperatures.csv')
df
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df.set_index('Date', inplace=True)
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.tail()
# Out:
#             Temp
# Date
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0

# %%
df.plot(figsize= (8,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.iloc[10]
# Out:
# Temp    16.2
# Name: 1981-01-11, dtype: float64

# %%
sns.pairplot(df)

# %%
df.loc['1981-01-12':'1981-01-19']
# Out:
#             Temp
# Date
# 1981-01-12  13.3
# 1981-01-13  16.7
# 1981-01-14  21.5
# 1981-01-15  25.0
# 1981-01-16  20.7
# 1981-01-17  20.6
# 1981-01-18  24.8
# 1981-01-19  17.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3650 entries, 1981-01-01 to 1990-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Temp    3650 non-null   float64
# dtypes: float64(1)
# memory usage: 186.1+ KB

# %%
df.describe()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %%
plt.figure(figsize=(20,6))
plt.plot(df.index, df['Temp'], color = 'blue', marker= 'o')
plt.title("The temprature by date")
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.show()

# %%
plt.hist(df['Temp'], bins=10, color='yellow')
plt.show()
